# %%
# tp : definir les fonctions manquantes qui determinent les 
# operations de base de python et le calcul entre des des vecteurs et des matrices .
# Out:
# Running cells with 'Python 3.13.13' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Windows/AppData/Local/Microsoft/WindowsApps/python3.13.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
#1. les operation de base en python

# Addition
def addition(a, b):
    return a + b

# Soustraction
def soustraction(a, b):
    return a - b

# Multiplication
def multiplication(a, b):
    return a * b

# Division
def division(a, b):
    if b != 0:
        return a / b
    else:
        return "Division impossible par zéro"
#Exemple

print(addition(4, 2))        # 6
print(soustraction(4, 2))    # 2
print(multiplication(4, 2))  # 8
print(division(4, 2))        # 2.0

#2. Calculs entre vecteurs

# Addition de vecteurs
def add_vecteurs(v1, v2):
    return [v1[i] + v2[i] for i in range(len(v1))]

# Produit scalaire
def produit_scalaire(v1, v2):
    return sum(v1[i] * v2[i] for i in range(len(v1)))

#Exemple

v1 = [1, 2, 3]
v2 = [4, 5, 6]

print(add_vecteurs(v1, v2))
print(produit_scalaire(v1, v2))
#Résultat :

[5, 7, 9]
32

#3. Calculs entre matrices

# Addition de matrices

def add_matrices(A, B):
    return [[A[i][j] + B[i][j] for j in range(len(A[0]))]
            for i in range(len(A))]


# Multiplication de matrices

def mult_matrices(A, B):
    resultat = [[0 for j in range(len(B[0]))]
                for i in range(len(A))]

    for i in range(len(A)):
        for j in range(len(B[0])):
            for k in range(len(B)):
                resultat[i][j] += A[i][k] * B[k][j]

    return resultat

#Exemple

A = [[1, 2],
     [3, 4]]

B = [[5, 6],
     [7, 8]]

print(add_matrices(A, B))
print(mult_matrices(A, B))
#Résultat :

[[6, 8], [10, 12]]

[[19, 22],
 [43, 50]]
#4. Avec NumPy (plus simple)

import numpy as np

A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])

print(A + B)
print(A @ B)
#+ → addition
#@ → multiplication matricielle
